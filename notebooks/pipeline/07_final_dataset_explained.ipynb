# %%
import pandas as pd

REPORT_PATH = "/Users/jakobschneider/Machine Learning/Data_LCC/reporting/ship_report_imo_2024.parquet"
df = pd.read_parquet(REPORT_PATH)

print("Shape:", df.shape)
print("Unique IMOs:", df["IMO"].nunique())
# Out:
# Shape: (6210, 21)
# Unique IMOs: 6210

# %%
df.columns
# Out:
# Index(['IMO', 'ship_name', 'VesselType', 'mrv_ship_type', 'report_year',
#        'ais_distance_nm_total', 'ais_time_hours_total', 'ais_points',
#        'sog_mean_kn', 'sog_p50_kn', 'sog_p95_kn', 'moving_share', 'Length',
#        'Width', 'draft_m_median', 'y_mrv_co2_per_nm_kg',
#        'y_pred_co2_per_nm_kg', 'residual_kg', 'residual_pct', 'flag_color',
#        'flag_reason'],
#       dtype='object')
